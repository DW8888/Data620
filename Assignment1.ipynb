# %% [markdown]
# ## 1. Import Required Libraries

# %%
# Import essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx  as nx
from networkx.drawing.nx_pydot import graphviz_layout

# %% [markdown]
# ## 2.Initialize the graph

# %%
G = nx.Graph()

# %% [markdown]
# ## 3. Node creation (nodes are nouns in our case characters)

# %%
names = [
    "Marcus", "Lucius", "Gaius", "Tiberius", "Aurelius",
    "Octavia", "Claudia", "Flavia", "Cornelia", "Valeria"
]

# %% [markdown]
# ## 4. Feeling edgy? lets define our edges

# %%
# 3. Add edges (same structure as the original Krackhardt kite graph)
edges = [
    ("Marcus", "Lucius"), ("Marcus", "Gaius"),
    ("Lucius", "Tiberius"), ("Lucius", "Aurelius"),
    ("Gaius", "Tiberius"), ("Octavia", "Claudia"),
    ("Tiberius", "Octavia"),
     ("Aurelius", "Claudia"),("Claudia","Lucius"),
    ("Octavia", "Cornelia"),("Gaius", "Claudia"),
    ("Claudia", "Cornelia"),("Gaius", "Octavia"),("Gaius", "Cornelia"),
    ("Flavia", "Valeria"), ("Aurelius", "Flavia"),("Gaius", "Lucius"),("Tiberius", "Marcus")
]
G.add_edges_from(edges)

# %% [markdown]
# ## 5. Visualizing our graph.

# %%
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color="lightblue",
        node_size=600, font_size=10, font_weight="bold")
plt.title("Krackhardt Kite Graph (Latin Names)", fontsize=14)
plt.show()

# %% [markdown]
# ## Lets print the graph dimensions

# %%
# 5. Print basic info
print("Number of nodes:", G.number_of_nodes())
print("Number of edges:", G.number_of_edges())
print("Nodes:", list(G.nodes()))
print("Edges:", list(G.edges()))
# Out:
# Number of nodes: 10
# Number of edges: 18
# Nodes: ['Marcus', 'Lucius', 'Gaius', 'Tiberius', 'Aurelius', 'Octavia', 'Claudia', 'Cornelia', 'Flavia', 'Valeria']
# Edges: [('Marcus', 'Lucius'), ('Marcus', 'Gaius'), ('Marcus', 'Tiberius'), ('Lucius', 'Tiberius'), ('Lucius', 'Aurelius'), ('Lucius', 'Claudia'), ('Lucius', 'Gaius'), ('Gaius', 'Tiberius'), ('Gaius', 'Claudia'), ('Gaius', 'Octavia'), ('Gaius', 'Cornelia'), ('Tiberius', 'Octavia'), ('Aurelius', 'Claudia'), ('Aurelius', 'Flavia'), ('Octavia', 'Claudia'), ('Octavia', 'Cornelia'), ('Claudia', 'Cornelia'), ('Flavia', 'Valeria')]

# %% [markdown]
# ## We can also plot the dufalt Krackhardt kite

# %%
P= nx.krackhardt_kite_graph()

# Draw it
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(P, seed=42)  # nice layout
nx.draw(P, pos, with_labels=True, node_color="red",
        node_size=1200, font_size=10, font_weight="bold")
plt.title("Krackhardt Kite Graph", fontsize=14)
plt.show()

# Print some basic info
print("Nodes:", G.nodes())
print("Edges:", G.edges())
# Out:
# Nodes: ['Marcus', 'Lucius', 'Gaius', 'Tiberius', 'Aurelius', 'Octavia', 'Claudia', 'Cornelia', 'Flavia', 'Valeria']
# Edges: [('Marcus', 'Lucius'), ('Marcus', 'Gaius'), ('Marcus', 'Tiberius'), ('Lucius', 'Tiberius'), ('Lucius', 'Aurelius'), ('Lucius', 'Claudia'), ('Lucius', 'Gaius'), ('Gaius', 'Tiberius'), ('Gaius', 'Claudia'), ('Gaius', 'Octavia'), ('Gaius', 'Cornelia'), ('Tiberius', 'Octavia'), ('Aurelius', 'Claudia'), ('Aurelius', 'Flavia'), ('Octavia', 'Claudia'), ('Octavia', 'Cornelia'), ('Claudia', 'Cornelia'), ('Flavia', 'Valeria')]
